# %%
import pandas as pd

# %%
pf = pd.read_csv(r"Data\Ecommerce Purchases.csv")

# %%
list(ecom.columns)
# Out:
# ['Address',
#  'Lot',
#  'AM or PM',
#  'Browser Info',
#  'Company',
#  'Credit Card',
#  'CC Exp Date',
#  'CC Security Code',
#  'CC Provider',
#  'Email',
#  'Job',
#  'IP Address',
#  'Language',
#  'Purchase Price',
#  'Browser']

# %% [markdown]
# # New Column

# %%
pf['Browser'] = ecom['Browser Info'].apply(lambda x: x.split('/')[0])
pf.head()
# Out:
#                                              Address    Lot AM or PM  \
# 0  16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1  9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                   Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3              7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4  23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
#
#                                         Browser Info  \
# 0  Opera/9.56.(X11; Linux x86_64; sl-SI) Presto/2...
# 1  Opera/8.93.(Windows 98; Win 9x 4.90; en-US) Pr...
# 2  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...
# 3  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_0 ...
# 4  Opera/9.58.(X11; Linux x86_64; it-IT) Presto/2...
#
#                            Company       Credit Card CC Exp Date  \
# 0                  Martinez-Herman  6011929061123406       02/20
# 1  Fletcher, Richards and Whitaker  3337758169645356       11/18
# ...

# %% [markdown]
# # Edit Column

# %%
pf['IP Address'].apply(lambda x: '1.1.1.1' if len(x)<12 else x )
# Out:
# 0       149.146.147.205
# 1          15.160.41.51
# 2        132.207.160.22
# 3          30.250.74.19
# 4          24.140.33.94
# 5         55.96.152.147
# 6        127.252.144.18
# 7        224.247.97.150
# 8       146.234.201.229
# 9         236.198.199.8
# 10              1.1.1.1
# 11       128.222.40.234
# 12       236.71.234.240
# 13         84.212.92.11
# 14              1.1.1.1
# 15        53.176.235.33
# 16         8.145.170.52
# 17        223.25.125.61
# 18       73.250.176.201
# 19       25.105.209.214
# 20        250.71.54.180
# 21        125.58.66.253
# 22        65.106.61.141
# 23       25.193.145.116
# 24       21.113.231.220
# 25        67.26.186.226
# 26       61.197.134.185
# 27       177.220.131.93
# 28      142.131.235.225
# 29      218.189.145.248
#              ...
# 9970       242.8.85.205
# 9971       81.2.189.127
# 9972      102.53.225.61
# 9973     201.88.164.123
# 9974    166.220.170.176
# 9975      114.197.6.210
# 9976      109.108.177.2
# ...

# %% [markdown]
# # Append new row
